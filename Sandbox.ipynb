# %%
# %matplotlib inline
import requests
import pandas as pd
import matplotlib.pyplot as plt
import pprint
import seaborn as sns
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
# This standard function takes in a Player ID and returns the URL necessary to
# acess that player's data. To access the list of all players with their player
# IDs, use PID = 000000
def getURL (PID, gameID):
    GURL =  'http://stats.nba.com/stats/shotchartdetail?CFID=33&CFPAR'\
            'AMS=2014-15&ContextFilter=&ContextMeasure=FGA&DateFrom=&D'\
            'ateTo=&GameID=' + gameID + \
            '&GameSegment=&LastNGames=0&' \
            'LeagueID=00&Location=&MeasureType=Base&Month=0&'\
            'OpponentTeamID=0&Outcome=&PaceAdjust=N&PerMode=PerGame' \
            '&Period=0&PlayerID=' + PID + \
            '&PlusMinus=N&Position=&Rank=N&RookieYear=&Season=2014-15&Seas'\
            'onSegment=&SeasonType=Regular+Season&TeamID=0&VsConferenc'\
            'e=&VsDivision=&mode=Advanced&showDetails=0&showShots=1&sh'\
            'owZones=0'
    return GURL
                    
players = {}
def findPlayerIDs ():
    response = requests.get(getURL('000000', ''))
    headers = response.json()['resultSets'][0]['headers']
    shots = response.json()['resultSets'][0]['rowSet']

    for i in range(len(shots)):
        players[shots[i][4]] = shots[i][3]

    # shot_df = pd.DataFrame(shots, columns=headers)

    pprint.pprint(players)
    print len(players)

findPlayerIDs()
# Out:
# {u'A.J. Price': 201985,
#  u'Aaron Brooks': 201166,
#  u'Aaron Gordon': 203932,
#  u'Adreian Payne': 203940,
#  u'Al Horford': 201143,
#  u'Al Jefferson': 2744,
#  u'Al-Farouq Aminu': 202329,
#  u'Alan Anderson': 101187,
#  u'Alec Burks': 202692,
#  u'Alex Kirk': 203945,
#  u'Alex Len': 203458,
#  u'Alexey Shved': 203144,
#  u'Alexis Ajinca': 201582,
#  u'Allen Crabbe': 203459,
#  u'Alonzo Gee': 202087,
#  u"Amar'e Stoudemire": 2405,
#  u'Amir Johnson': 101161,
#  u'Anderson Varejao': 2760,
#  u'Andre Dawkins': 203958,
#  u'Andre Drummond': 203083,
#  u'Andre Iguodala': 2738,
#  u'Andre Miller': 1889,
#  u'Andre Roberson': 203460,
#  u'Andrea Bargnani': 200745,
#  u'Andrei Kirilenko': 1905,
#  u'Andrew Bogut': 101106,
#  u'Andrew Nicholson': 203094,
#  u'Andrew Wiggins': 203952,
#  u'Anthony Bennett': 203461,
#  u'Anthony Davis': 203076,
#  u'Anthony Morrow': 201627,
#  u'Anthony Tolliver': 201229,
#  u'Archie Goodwin': 203462,
#  u'Arinze Onuaku': 202620,
#  u'Aron Baynes': 203382,
#  u'Arron Afflalo': 201167,
#  u'Austin Daye': 201948,
#  u'Austin Rivers': 203085,
#  u'Avery Bradley': 202340,
#  u'Ben Gordon': 2732,
#  u'Ben McLemore': 203463,
#  u'Beno Udrih': 2757,
#  u'Bernard James': 203108,
#  u'Bismack Biyombo': 202687,
#  u'Blake Griffin': 201933,
#  u'Bojan Bogdanovic': 202711,
#  u'Boris Diaw': 2564,
#  u'Bradley Beal': 203078,
#  u'Brandan Wright': 201148,
#  u'Brandon Bass': 101138,
#  u'Rudy Gay': 200752,
#  u'Rudy Gobert': 203497,
#  u'Russ Smith': 203893,
#  u'Russell Westbrook': 201566,
#  u'Ryan Anderson': 201583,
#  u'Ryan Hollins': 200797,
#  u'Ryan Kelly': 203527,
#  u'Samuel Dalembert': 2223,
#  u'Sean Kilpatrick': 203930,
#  u'Sebastian Telfair': 2742,
#  u'Serge Ibaka': 201586,
#  u'Sergey Karasev': 203508,
#  u'Seth Curry': 203552,
#  u'Shabazz Muhammad': 203498,
#  u'Shabazz Napier': 203894,
#  u'Shane Larkin': 203499,
#  u'Shannon Brown': 200769,
#  u'Shaun Livingston': 2733,
#  u'Shavlik Randolph': 101183,
#  u'Shawn Marion': 1890,
#  u'Shawne Williams': 200761,
#  u'Shayne Whittington': 203963,
#  u'Shelvin Mack': 202714,
#  u'Sim Bhullar': 204021,
#  u'Solomon Hill': 203524,
#  u'Spencer Dinwiddie': 203915,
#  u'Spencer Hawes': 201150,
#  u'Stephen Curry': 201939,
#  u'Steve Blake': 2581,
#  u'Steve Novak': 200779,
#  u'Steven Adams': 203500,
#  u'TJ Warren': 203933,
#  u'Taj Gibson': 201959,
#  u'Tarik Black': 204028,
#  u'Tayshaun Prince': 2419,
#  u'Terrence Jones': 203093,
#  u'Terrence Ross': 203082,
#  u'Thabo Sefolosha': 200757,
#  u'Thaddeus Young': 201152,
#  u'Thomas Robinson': 203080,
#  u'Tiago Splitter': 201168,
#  u'Tim Duncan': 1495,
#  u'Tim Frazier': 204025,
#  u'Tim Hardaway Jr.': 203501,
#  u'Timofey Mozgov': 202389,
#  u'Tobias Harris': 202699,
#  u'Toney Douglas': 201962,
#  u'Tony Allen': 2754,
#  u'Tony Parker': 2225,
#  u'Tony Snell': 203503,
#  u'Tony Wroten': 203100,
#  u'Toure Murry': 203315,
#  u'Travis Wear': 204037,
#  u'Trevor Ariza': 2772,
#  u'Trevor Booker': 202344,
#  u'Trey Burke': 203504,
#  u'Tristan Thompson': 202684,
#  u'Troy Daniels': 203584,
#  u'Ty Lawson': 201951,
#  u'Tyler Ennis': 203898,
#  u'Tyler Hansbrough': 201946,
#  u'Tyler Johnson': 204020,
#  u'Tyler Zeller': 203092,
#  u'Tyreke Evans': 201936,
#  u'Tyrus Thomas': 200748,
#  u'Tyson Chandler': 2199,
#  u'Udonis Haslem': 2617,
#  u'Vander Blue': 203505,
#  u'Victor Claver': 201964,
#  u'Victor Oladipo': 203506,
#  u'Vince Carter': 1713,
#  u'Wayne Ellington': 201961,
#  u'Wesley Johnson': 202325,
#  u'Wesley Matthews': 202083,
#  u'Will Barton': 203115,
#  u'Will Bynum': 101198,
#  u'Will Cherry': 203805,
#  u'Willie Green': 2584,
#  u'Wilson Chandler': 201163,
#  u'Xavier Henry': 202333,
#  u'Zach LaVine': 203897,
#  u'Zach Randolph': 2216,
#  u'Zaza Pachulia': 2585,
#  u'Zoran Dragic': 204054}
# 490

# %%
gameID = 21400213
eventID = 1




currentEvent = getEvent(gameID, eventID)

while currentEvent:
    
    
    eventID += 1
    currentEvent = getEvent(gameID, eventID)

print eventID
# Out:
#   File "<ipython-input-16-ac3d1099d0cc>", line 4
#     getEvent(gameID, eventID):
#                              ^
# SyntaxError: invalid syntax

# %%
def update(d1, d2):
    for k,v in d2.items():
        if k in d1.keys():
            d1[k] = [d1[k],v]
        else:
            d1[k] = v

def getShots(PID, gameID):
    shotEvents = {}
    
    SCurl = getURL(str(PID),str(gameID).zfill(10))
    # Get the webpage containing the data
    response = requests.get(SCurl)
    if response:
        # Grab the headers to be used as column headers for our DataFrame
        headers = response.json()['resultSets'][0]['headers']
        # Grab the shot chart data
        shots = response.json()['resultSets'][0]['rowSet']
        for shot in shots:
            X = {'playerid':     shot[3], 
                 'teamid':       shot[5], 
                 'period':       shot[7], 
                 'minutesLeft':  shot[8],
                 'secondsLeft':  shot[9],
                 'actionType':   shot[11],
                 'shotType':     shot[12],
                 'shotDistance': shot[16],
                 'shotLocX':     shot[17],
                 'shotLoxY':     shot[18],
                 'shotMadeFlag': shot[20]}

            update(shotEvents,{shot[2]: X})
        
    return shotEvents

        
print getShots(203457, 21400213)
# Out:
# {377: {'shotDistance': 0, 'period': 4, 'minutesLeft': 11, 'shotType': u'2PT Field Goal', 'actionType': u'Slam Dunk Shot', 'shotLocX': 0, 'shotLoxY': 1, 'secondsLeft': 0, 'playerid': 203457, 'shotMadeFlag': 1, 'teamid': 1610612755}, 380: {'shotDistance': 0, 'period': 4, 'minutesLeft': 10, 'shotType': u'2PT Field Goal', 'actionType': u'Alley Oop Dunk Shot', 'shotLocX': 0, 'shotLoxY': 1, 'secondsLeft': 25, 'playerid': 203457, 'shotMadeFlag': 1, 'teamid': 1610612755}, 142: {'shotDistance': 5, 'period': 2, 'minutesLeft': 9, 'shotType': u'2PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': -34, 'shotLoxY': 44, 'secondsLeft': 25, 'playerid': 203457, 'shotMadeFlag': 0, 'teamid': 1610612755}, 167: {'shotDistance': 16, 'period': 2, 'minutesLeft': 6, 'shotType': u'2PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': -157, 'shotLoxY': 48, 'secondsLeft': 40, 'playerid': 203457, 'shotMadeFlag': 0, 'teamid': 1610612755}}

# %%
gameID = 21400213
eventID = 1
stopOfGame=0

def getEvent(gameID, eventID):
    return requests.get('http://stats.nba.com/stats/locations_getmoments/?eventid='+str(eventID)+'&gameid='+str(gameID).zfill(10))


currentEvent = getEvent(gameID, eventID)

visitorID = currentEvent.json()['visitor']['teamid']
homeID = currentEvent.json()['home']['teamid']

shotRecord = {}
players = []
for player in currentEvent.json()['visitor']['players']:
    players.append({'teamid':visitorID, 'playerid': player['playerid']})
    update(shotRecord, getShots(player['playerid'], gameID))
for player in currentEvent.json()['home']['players']:
    players.append({'teamid':homeID, 'playerid': player['playerid']})
    update(shotRecord, getShots(player['playerid'], gameID))
    
print shotRecord

eventsWithShots = shotRecord.keys()
# Out:
amid': 1610612751}, 23: {'shotDistance': 23, 'period': 1, 'minutesLeft': 7, 'shotType': u'3PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': -237, 'shotLoxY': -22, 'secondsLeft': 50, 'playerid': 202711, 'shotMadeFlag': 0, 'teamid': 1610612751}, 30: {'shotDistance': 19, 'period': 1, 'minutesLeft': 7, 'shotType': u'2PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': -71, 'shotLoxY': 181, 'secondsLeft': 39, 'playerid': 203156, 'shotMadeFlag': 0, 'teamid': 1610612755}, 32: {'shotDistance': 24, 'period': 1, 'minutesLeft': 7, 'shotType': u'3PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': 197, 'shotLoxY': 142, 'secondsLeft': 27, 'playerid': 2207, 'shotMadeFlag': 1, 'teamid': 1610612751}, 34: {'shotDistance': 1, 'period': 1, 'minutesLeft': 7, 'shotType': u'2PT Field Goal', 'actionType': u'Driving Layup Shot', 'shotLocX': -4, 'shotLoxY': -19, 'secondsLeft': 0, 'playerid': 201572, 'shotMadeFlag': 1, 'teamid': 1610612751}, 35: {'shotDistance': 23, 'period': 1, 'minutesLeft': 6, 'shotType': u'3PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': 239, 'shotLoxY': -10, 'secondsLeft': 43, 'playerid': 201601, 'shotMadeFlag': 1, 'teamid': 1610612755}, 42: {'shotDistance': 27, 'period': 1, 'minutesLeft': 6, 'shotType': ...

# %%
print eventsWithShots
# Out:
# [3, 516, 8, 9, 10, 11, 13, 14, 16, 17, 19, 20, 23, 30, 32, 34, 35, 42, 44, 51, 53, 54, 55, 58, 67, 78, 80, 82, 83, 85, 91, 92, 93, 101, 102, 107, 113, 118, 120, 122, 124, 131, 132, 136, 138, 142, 144, 145, 147, 150, 152, 154, 156, 158, 166, 167, 184, 186, 196, 203, 206, 207, 208, 210, 213, 215, 217, 218, 220, 222, 224, 225, 233, 234, 235, 238, 240, 241, 246, 248, 250, 252, 254, 255, 257, 258, 260, 261, 263, 267, 270, 272, 274, 275, 277, 279, 289, 290, 292, 293, 295, 297, 301, 303, 305, 306, 308, 310, 316, 317, 320, 321, 323, 327, 328, 330, 332, 334, 339, 350, 351, 364, 366, 371, 377, 380, 387, 389, 390, 393, 395, 396, 399, 400, 401, 402, 410, 412, 418, 420, 428, 430, 439, 441, 444, 452, 463, 468, 470, 477, 485, 487, 488, 497, 501, 509]

# %%
eventID = 1
currentEvent = getEvent(gameID, eventID)
stopOfGame=0
while stopOfGame < 5:
    if currentEvent:
        stopOfGame = 0
        
        C = currentEvent.json()
        if eventID in eventsWithShots:
            print eventID
            C['shots'] = shotRecord[eventID]
        else:
            C['shots'] = {}

        # Replace this with a read to database
#         if eventID == 3:
#             pprint(C)
        
    else:
        stopOfGame += 1
    
    eventID += 1
    currentEvent = getEvent(gameID, eventID)

print eventID
# Out:
# 3
# 8
# 9
# 10
# 11
# 13
# 14
# 16
# 17
# 19
# 20
# 23
# 30
# 32
# 34
# 35
# 42
# 44
# 51
# 53
# 54
# 55
# 58
# 67
# 78
# 80
# 82
# 83
# 85
# 91
# 92
# 93
# 101
# 102
# 107
# 113
# 118
# 120
# 122
# 124
# 131
# 132
# 136
# 138
# 142
# 144
# 145
# 147
# 150
# 152
# 154
# 156
# 158
# 166
# 167
# 184
# 186
# 196
# 203
# 206
# 207
# 208
# 210
# 213
# 215
# 217
# 218
# 220
# 222
# 224
# 225
# 233
# 234
# 235
# 238
# 240
# 241
# 246
# 248
# 250
# 252
# 254
# 255
# 257
# 258
# 260
# 261
# 263
# 267
# 270
# 272
# 274
# 275
# 277
# 279
# 289
# 290
# 292
# 293
# 295
# 297
# 301
# 303
# 305
# 306
# 308
# 310
# 316
# 317
# 320
# 321
# 323
# 327
# 328
# 330
# 332
# 334
# 339
# 350
# 351
# 364
# 366
# 371
# 377
# 380
# 387
# 389
# 390
# 393
# 395
# 396
# 399
# 400
# 401
# 402
# 410
# 412
# 418
# 420
# 428
# 430
# 439
# 441
# 444
# 452
# 463
# 468
# 470
# 477
# 485
# 487
# 488
# 497
# 501
# 509
# 516
# 532

# %% [markdown]
# shots = {'hello':'there'}
#
# def update(d1, d2):
#     for k,v in d2.items():
#         if k in d1.keys():
#             d1[k] = [d1[k],v]
#         else:
#             d1[k] = v
# update(shots,{'hello':'goodbye'})
# print shots

# %%
print shotRecord
# Out:
# {3: {'shotDistance': 17, 'period': 1, 'minutesLeft': 11, 'shotType': u'2PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': -136, 'shotLoxY': 105, 'secondsLeft': 25, 'playerid': 201572, 'shotMadeFlag': 1, 'teamid': 1610612751}, 516: {'shotDistance': 24, 'period': 4, 'minutesLeft': 0, 'shotType': u'3PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': 166, 'shotLoxY': 186, 'secondsLeft': 8, 'playerid': 203138, 'shotMadeFlag': 0, 'teamid': 1610612755}, 8: {'shotDistance': 4, 'period': 1, 'minutesLeft': 10, 'shotType': u'2PT Field Goal', 'actionType': u'Running Jump Shot', 'shotLocX': 32, 'shotLoxY': 36, 'secondsLeft': 16, 'playerid': 2207, 'shotMadeFlag': 1, 'teamid': 1610612751}, 9: {'shotDistance': 24, 'period': 1, 'minutesLeft': 9, 'shotType': u'3PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': -112, 'shotLoxY': 220, 'secondsLeft': 58, 'playerid': 201601, 'shotMadeFlag': 1, 'teamid': 1610612755}, 10: {'shotDistance': 0, 'period': 1, 'minutesLeft': 9, 'shotType': u'2PT Field Goal', 'actionType': u'Layup Shot', 'shotLocX': -2, 'shotLoxY': 1, 'secondsLeft': 42, 'playerid': 101114, 'shotMadeFlag': 1, 'teamid': 1610612751}, 11: {'shotDistance': 6, 'period': 1, 'minutesLeft': 9, 'shotType': u'2PT Field Goal', 'actionType': u'Jump Shot', 'shotLocX': -45, 'shotLoxY': 52, 'secondsLeft': 31, 'playerid': 203487, 'shotMadeFlag': 0, 'teamid': 1610612755}, 13: {'shotDistance': 2, 'period': 1, 'minutesLeft': 9, 'shotType': u'2PT Field Goal', 'actionType': u'Driving Layup Shot',